# %%
import numpy as np
import matplotlib.pyplot as plt
v=np.array([3,2])
plt.plot([1,v[0]],[2,v[1]])

v=np.array([1,2])
plt.plot([1,v[0]],[1,v[1]])
v=np.array([3,1])
plt.plot([1,v[0]],[1,v[1]])


v=np.array([3,0])
plt.plot([1,v[0]],[0,v[1]])

v=np.array([3,2])
plt.plot([1,v[0]],[2,v[1]])


v=np.array([3,1])
plt.plot([3,v[0]],[0,v[1]])


v=np.array([5,2])
plt.plot([5,v[0]],[0,v[1]])
v=np.array([7,1])
plt.plot([5,v[0]],[1,v[1]])
v=np.array([7,2])
plt.plot([7,v[0]],[0,v[1]])
v=np.array([8,2])
plt.plot([8,v[0]],[0,v[1]])
v=np.array([10,0])
plt.plot([8,v[0]],[0,v[1]])
v=np.array([10,2])
plt.plot([10,v[0]],[0,v[1]])
v=np.array([10,2])
plt.plot([8,v[0]],[2,v[1]])
v=np.array([12,2])
plt.plot([11,v[0]],[0,v[1]])
v=np.array([13,0])
plt.plot([12,v[0]],[2,v[1]])
v=np.array([12.5,1])
plt.plot([11,v[0]],[1,v[1]])
v=np.array([14,2])
plt.plot([14,v[0]],[0,v[1]])
v=np.array([15,2])
plt.plot([15,v[0]],[0,v[1]])
v=np.array([16,2])
plt.plot([16,v[0]],[0,v[1]])
v=np.array([16,1])
plt.plot([15,v[0]],[1,v[1]])
v=np.array([16,2])
plt.plot([15,v[0]],[2,v[1]])
v=np.array([16,0])
plt.plot([15,v[0]],[0,v[1]])
















plt.axis([0,30,-4,4])
# Out:
# (0.0, 30.0, -4.0, 4.0)
